# %%
# Import required libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Display plots inside Jupyter Notebook
# %matplotlib inline

# Set visualization style
plt.style.use('ggplot')

# Ignore warning messages
import warnings
warnings.filterwarnings('ignore')

# %%
# Load dataset
df = pd.read_csv("KADIRS_Tax_Compliance_2000_Rows.csv")

# %%
# Display first five rows
df.head()
# Out:
#    record_id  taxpayer_id                tin                   business_name  \
# 0          1       100251  KAD-TIN-202500000               Robinson and Sons
# 1          2       100226  KAD-TIN-202500001        Conrad, Colon and Wilson
# 2          3       100045  KAD-TIN-202500002                    Davidson LLC
# 3          4       100285  KAD-TIN-202500003                    Burch-Waller
# 4          5       100333  KAD-TIN-202500004  Alvarez, Rodriguez and Bennett
#
#         owner_name taxpayer_type business_sector           lga  \
# 0        Kayla May    Individual             ICT         Igabi
# 1      Haley Lewis           SME      Healthcare  Kaduna North
# 2  Barbara Buckley     Corporate   Manufacturing       Makarfi
# 3        Jon Smith           SME     Agriculture          Jaba
# 4  Amanda Gonzalez    Individual             ICT        Chikun
#
#   registration_date  tax_year  ... payment_method payment_date audit_status  \
# ...

# %%
df.tail()
# Out:
#       record_id  taxpayer_id                tin                business_name  \
# 1995       1996       100394  KAD-TIN-202501995  Mathews, Thornton and Young
# 1996       1997       100502  KAD-TIN-202501996                  Freeman Ltd
# 1997       1998       100052  KAD-TIN-202501997       Arroyo, Graham and Lee
# 1998       1999       100170  KAD-TIN-202501998                 Beasley-Duke
# 1999       2000       100691  KAD-TIN-202501999  Castro, Anderson and Peters
#
#              owner_name taxpayer_type business_sector      lga  \
# 1995      John Carrillo    Individual     Agriculture  Kagarko
# 1996  Danielle Gonzales    Individual   Manufacturing   Kachia
# 1997     Paula Williams    Individual      Healthcare     Lere
# 1998       Andrew Meyer           SME          Retail    Kudan
# 1999     Antonio Pierce    Individual   Manufacturing    Kaura
#
#      registration_date  tax_year  ... payment_method payment_date  \
# ...

# %%
# Number of rows and columns
df.shape
# Out:
# (2000, 29)

# %%
list(df.columns)
# Out:
# ['record_id',
#  'taxpayer_id',
#  'tin',
#  'business_name',
#  'owner_name',
#  'taxpayer_type',
#  'business_sector',
#  'lga',
#  'registration_date',
#  'tax_year',
#  'tax_month',
#  'tax_type',
#  'filing_due_date',
#  'filing_date',
#  'filing_status',
#  'amount_assessed',
#  'amount_paid',
#  'outstanding_balance',
#  'payment_status',
#  'payment_method',
#  'payment_date',
#  'audit_status',
#  'audit_result',
#  'penalty',
#  'annual_turnover',
#  'risk_level',
#  'compliance_score',
#  'revenue_office',
#  'notification_sent']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 29 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   record_id            2000 non-null   int64
#  1   taxpayer_id          2000 non-null   int64
#  2   tin                  2000 non-null   object
#  3   business_name        2000 non-null   object
#  4   owner_name           2000 non-null   object
#  5   taxpayer_type        2000 non-null   object
#  6   business_sector      2000 non-null   object
#  7   lga                  2000 non-null   object
#  8   registration_date    2000 non-null   object
#  9   tax_year             2000 non-null   int64
#  10  tax_month            2000 non-null   object
#  11  tax_type             2000 non-null   object
#  12  filing_due_date      2000 non-null   object
#  13  filing_date          1351 non-null   object
#  14  filing_status        2000 non-null   object
# ...

# %%
df.describe()
# Out:
#          record_id    taxpayer_id  tax_year  amount_assessed   amount_paid  \
# count  2000.000000    2000.000000    2000.0     2.000000e+03  2.000000e+03
# mean   1000.500000  100344.825000    2025.0     2.590214e+06  1.961347e+06
# std     577.494589     200.586328       0.0     1.440362e+06  1.523135e+06
# min       1.000000  100001.000000    2025.0     5.154600e+04  3.590000e+02
# 25%     500.750000  100167.750000    2025.0     1.348322e+06  5.783630e+05
# 50%    1000.500000  100339.500000    2025.0     2.652268e+06  1.605515e+06
# 75%    1500.250000  100520.000000    2025.0     3.825827e+06  3.269239e+06
# max    2000.000000  100700.000000    2025.0     4.998164e+06  4.996304e+06
#
#        outstanding_balance        penalty  annual_turnover  compliance_score
# count         2.000000e+03    2000.000000     2.000000e+03       2000.000000
# mean          6.288673e+05   99467.005000     2.526930e+08         59.616500
# ...

# %%
df.describe(include='object')
# Out:
#                       tin business_name        owner_name taxpayer_type  \
# count                2000          2000              2000          2000
# unique               2000          1918              1968             3
# top     KAD-TIN-202500000  Williams Inc  Michael Castillo     Corporate
# freq                    1             5                 4           698
#
#        business_sector    lga registration_date tax_month  tax_type  \
# count             2000   2000              2000      2000      2000
# unique               5     23               497        12         4
# top         Healthcare  Igabi        25/01/2025       Sep  Road Tax
# freq               414    102                12       197       536
#
#        filing_due_date filing_date filing_status payment_status  \
# count             2000        1351          2000           2000
# unique             669         582             3              2
# top         28/06/2025  17/01/2025         Filed           Paid
# ...

# %%
df.isnull().sum()
# Out:
# record_id                0
# taxpayer_id              0
# tin                      0
# business_name            0
# owner_name               0
# taxpayer_type            0
# business_sector          0
# lga                      0
# registration_date        0
# tax_year                 0
# tax_month                0
# tax_type                 0
# filing_due_date          0
# filing_date            649
# filing_status            0
# amount_assessed          0
# amount_paid              0
# outstanding_balance      0
# payment_status           0
# payment_method           0
# payment_date             0
# audit_status             0
# audit_result             0
# penalty                  0
# annual_turnover          0
# risk_level               0
# compliance_score         0
# revenue_office           0
# notification_sent        0
# dtype: int64

# %%
missing = df.isnull().sum()

missing[missing > 0]
# Out:
# filing_date    649
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.sample(10)
# Out:
#       record_id  taxpayer_id                tin                 business_name  \
# 160         161       100208  KAD-TIN-202500160                  Ramos-Murray
# 1909       1910       100501  KAD-TIN-202501909  Gibson, Reyes and Washington
# 1861       1862       100227  KAD-TIN-202501861  Mathis, Martinez and Swanson
# 1245       1246       100300  KAD-TIN-202501245             Johnston and Sons
# 1784       1785       100009  KAD-TIN-202501784               Jackson-Frazier
# 1716       1717       100375  KAD-TIN-202501716                    Bailey LLC
# 610         611       100311  KAD-TIN-202500610      Powell, Boyer and Garner
# 868         869       100534  KAD-TIN-202500868                   Brown-Perez
# 197         198       100487  KAD-TIN-202500197                Mitchell Group
# 1613       1614       100071  KAD-TIN-202501613        Ray, Sims and Mcdonald
#
#              owner_name taxpayer_type business_sector           lga  \
# ...

# %%
df.dtypes
# Out:
# record_id               int64
# taxpayer_id             int64
# tin                    object
# business_name          object
# owner_name             object
# taxpayer_type          object
# business_sector        object
# lga                    object
# registration_date      object
# tax_year                int64
# tax_month              object
# tax_type               object
# filing_due_date        object
# filing_date            object
# filing_status          object
# amount_assessed         int64
# amount_paid             int64
# outstanding_balance     int64
# payment_status         object
# payment_method         object
# payment_date           object
# audit_status           object
# audit_result           object
# penalty                 int64
# annual_turnover         int64
# risk_level             object
# compliance_score        int64
# revenue_office         object
# notification_sent      object
# dtype: object

# %%
Initial Dataset Observations

The dataset consists of approximately 2,000 records and 29 variables related to taxpayer registration, tax filing, payments, audits, and compliance metrics. Initial exploration shows a combination of numerical, categorical, and date variables. The dataset appears suitable for further analysis, although additional inspection will be carried out to identify missing values, duplicate records, inconsistent data entries, and incorrect data types before performing exploratory data analysis.
